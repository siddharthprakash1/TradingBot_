# %%
# !pip install lumibot==2.9.13
# Out:
# Requirement already satisfied: lumibot==2.9.13 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (2.9.13)
# Requirement already satisfied: polygon-api-client>=1.13.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (1.13.5)
# Requirement already satisfied: alpaca-py>=0.13.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (0.20.3)
# Requirement already satisfied: alpha-vantage in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (2.3.1)
# Requirement already satisfied: ibapi==9.81.1.post1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (9.81.1.post1)
# Requirement already satisfied: yfinance in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (0.2.37)
# Requirement already satisfied: matplotlib>=3.3.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (3.8.4)
# Requirement already satisfied: quandl in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (3.7.0)
# Requirement already satisfied: pandas<=2.0.3,>=2.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (2.0.3)
# Requirement already satisfied: pandas-datareader in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (0.10.0)
# Requirement already satisfied: pandas-market-calendars>=4.3.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (4.4.0)
# Requirement already satisfied: plotly in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (5.20.0)
# Requirement already satisfied: flask>=2.2.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (3.0.2)
# Requirement already satisfied: flask-socketio in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (5.3.6)
# Requirement already satisfied: flask-sqlalchemy in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (3.1.1)
# Requirement already satisfied: flask-marshmallow in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (1.2.1)
# Requirement already satisfied: flask-security in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (3.0.0)
# Requirement already satisfied: marshmallow-sqlalchemy in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (1.0.0)
# Requirement already satisfied: email-validator in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (2.1.1)
# Requirement already satisfied: bcrypt in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (4.1.2)
# Requirement already satisfied: pytest in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (8.1.1)
# Requirement already satisfied: scipy==1.10.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (1.10.1)
# Requirement already satisfied: ipython in c:\users\dell\appdata\roaming\python\python311\site-packages (from lumibot==2.9.13) (8.23.0)
# Requirement already satisfied: quantstats>=0.0.62 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (0.0.62)
# Requirement already satisfied: python-dotenv in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (1.0.1)
# Requirement already satisfied: ccxt==4.1.78 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (4.1.78)
# Requirement already satisfied: termcolor in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (2.4.0)
# Requirement already satisfied: jsonpickle in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (3.0.3)
# Requirement already satisfied: apscheduler==3.10.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (3.10.4)
# Requirement already satisfied: appdirs in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (1.4.4)
# Requirement already satisfied: pyarrow in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (15.0.2)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from lumibot==2.9.13) (4.66.2)
# Requirement already satisfied: six>=1.4.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from apscheduler==3.10.4->lumibot==2.9.13) (1.16.0)
# Requirement already satisfied: pytz in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from apscheduler==3.10.4->lumibot==2.9.13) (2024.1)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from apscheduler==3.10.4->lumibot==2.9.13) (5.2)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from ccxt==4.1.78->lumibot==2.9.13) (65.5.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from ccxt==4.1.78->lumibot==2.9.13) (2024.2.2)
# Requirement already satisfied: requests>=2.18.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from ccxt==4.1.78->lumibot==2.9.13) (2.31.0)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from ccxt==4.1.78->lumibot==2.9.13) (42.0.5)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from ccxt==4.1.78->lumibot==2.9.13) (4.10.0)
# Requirement already satisfied: aiohttp>=3.8 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from ccxt==4.1.78->lumibot==2.9.13) (3.9.3)
# Requirement already satisfied: aiodns>=1.1.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from ccxt==4.1.78->lumibot==2.9.13) (3.2.0)
# Requirement already satisfied: yarl>=1.7.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from ccxt==4.1.78->lumibot==2.9.13) (1.9.4)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scipy==1.10.1->lumibot==2.9.13) (1.26.4)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from alpaca-py>=0.13.1->lumibot==2.9.13) (1.0.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from alpaca-py>=0.13.1->lumibot==2.9.13) (2.6.4)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from alpaca-py>=0.13.1->lumibot==2.9.13) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from alpaca-py>=0.13.1->lumibot==2.9.13) (12.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask>=2.2.2->lumibot==2.9.13) (3.0.2)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask>=2.2.2->lumibot==2.9.13) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask>=2.2.2->lumibot==2.9.13) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask>=2.2.2->lumibot==2.9.13) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask>=2.2.2->lumibot==2.9.13) (1.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.3->lumibot==2.9.13) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.3->lumibot==2.9.13) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.3->lumibot==2.9.13) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.3->lumibot==2.9.13) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.3->lumibot==2.9.13) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.3->lumibot==2.9.13) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.3->lumibot==2.9.13) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.3->lumibot==2.9.13) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandas<=2.0.3,>=2.0.0->lumibot==2.9.13) (2024.1)
# Requirement already satisfied: exchange-calendars>=3.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandas-market-calendars>=4.3.1->lumibot==2.9.13) (4.5.3)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.9 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from polygon-api-client>=1.13.3->lumibot==2.9.13) (1.26.18)
# Requirement already satisfied: seaborn>=0.9.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from quantstats>=0.0.62->lumibot==2.9.13) (0.13.2)
# Requirement already satisfied: tabulate>=0.8.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from quantstats>=0.0.62->lumibot==2.9.13) (0.9.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from yfinance->lumibot==2.9.13) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from yfinance->lumibot==2.9.13) (5.2.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from yfinance->lumibot==2.9.13) (2.4.1)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from yfinance->lumibot==2.9.13) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from yfinance->lumibot==2.9.13) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from yfinance->lumibot==2.9.13) (1.1)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from email-validator->lumibot==2.9.13) (2.6.1)
# Requirement already satisfied: idna>=2.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from email-validator->lumibot==2.9.13) (3.6)
# Requirement already satisfied: marshmallow>=3.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask-marshmallow->lumibot==2.9.13) (3.21.1)
# Requirement already satisfied: Flask-Login>=0.3.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask-security->lumibot==2.9.13) (0.6.3)
# Requirement already satisfied: Flask-Mail>=0.7.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask-security->lumibot==2.9.13) (0.9.1)
# Requirement already satisfied: Flask-Principal>=0.3.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask-security->lumibot==2.9.13) (0.4.0)
# Requirement already satisfied: Flask-WTF>=0.13.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask-security->lumibot==2.9.13) (1.2.1)
# Requirement already satisfied: Flask-BabelEx>=0.9.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask-security->lumibot==2.9.13) (0.9.4)
# Requirement already satisfied: passlib>=1.7 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask-security->lumibot==2.9.13) (1.7.4)
# Requirement already satisfied: python-socketio>=5.0.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask-socketio->lumibot==2.9.13) (5.11.2)
# Requirement already satisfied: sqlalchemy>=2.0.16 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from flask-sqlalchemy->lumibot==2.9.13) (2.0.29)
# Requirement already satisfied: decorator in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipython->lumibot==2.9.13) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipython->lumibot==2.9.13) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipython->lumibot==2.9.13) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipython->lumibot==2.9.13) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipython->lumibot==2.9.13) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipython->lumibot==2.9.13) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipython->lumibot==2.9.13) (5.14.2)
# Requirement already satisfied: colorama in c:\users\dell\appdata\roaming\python\python311\site-packages (from ipython->lumibot==2.9.13) (0.4.6)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from plotly->lumibot==2.9.13) (8.2.3)
# Requirement already satisfied: iniconfig in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pytest->lumibot==2.9.13) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=1.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pytest->lumibot==2.9.13) (1.4.0)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from quandl->lumibot==2.9.13) (0.5.1)
# Requirement already satisfied: more-itertools in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from quandl->lumibot==2.9.13) (10.2.0)
# Requirement already satisfied: pycares>=4.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiodns>=1.1.1->ccxt==4.1.78->lumibot==2.9.13) (4.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.8->ccxt==4.1.78->lumibot==2.9.13) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.8->ccxt==4.1.78->lumibot==2.9.13) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.8->ccxt==4.1.78->lumibot==2.9.13) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.8->ccxt==4.1.78->lumibot==2.9.13) (6.0.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance->lumibot==2.9.13) (2.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=2.6.1->ccxt==4.1.78->lumibot==2.9.13) (1.16.0)
# Requirement already satisfied: pyluach in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from exchange-calendars>=3.3->pandas-market-calendars>=4.3.1->lumibot==2.9.13) (2.2.0)
# Requirement already satisfied: toolz in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from exchange-calendars>=3.3->pandas-market-calendars>=4.3.1->lumibot==2.9.13) (0.12.1)
# Requirement already satisfied: korean-lunar-calendar in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from exchange-calendars>=3.3->pandas-market-calendars>=4.3.1->lumibot==2.9.13) (0.3.1)
# Requirement already satisfied: Babel>=1.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from Flask-BabelEx>=0.9.3->flask-security->lumibot==2.9.13) (2.14.0)
# Requirement already satisfied: speaklater>=1.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from Flask-BabelEx>=0.9.3->flask-security->lumibot==2.9.13) (1.3)
# Requirement already satisfied: wtforms in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from Flask-WTF>=0.13.1->flask-security->lumibot==2.9.13) (3.1.2)
# Requirement already satisfied: webencodings in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from html5lib>=1.1->yfinance->lumibot==2.9.13) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->lumibot==2.9.13) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from Jinja2>=3.1.2->flask>=2.2.2->lumibot==2.9.13) (2.1.5)
# Requirement already satisfied: wcwidth in c:\users\dell\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->lumibot==2.9.13) (0.2.13)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py>=0.13.1->lumibot==2.9.13) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py>=0.13.1->lumibot==2.9.13) (2.16.3)
# Requirement already satisfied: bidict>=0.21.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from python-socketio>=5.0.2->flask-socketio->lumibot==2.9.13) (0.23.1)
# Requirement already satisfied: python-engineio>=4.8.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from python-socketio>=5.0.2->flask-socketio->lumibot==2.9.13) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.18.4->ccxt==4.1.78->lumibot==2.9.13) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=2.0.16->flask-sqlalchemy->lumibot==2.9.13) (3.0.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from stack-data->ipython->lumibot==2.9.13) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from stack-data->ipython->lumibot==2.9.13) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\dell\appdata\roaming\python\python311\site-packages (from stack-data->ipython->lumibot==2.9.13) (0.2.2)
# Requirement already satisfied: pycparser in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt==4.1.78->lumibot==2.9.13) (2.22)
# Requirement already satisfied: simple-websocket>=0.10.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from python-engineio>=4.8.0->python-socketio>=5.0.2->flask-socketio->lumibot==2.9.13) (1.0.0)
# Requirement already satisfied: wsproto in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio>=5.0.2->flask-socketio->lumibot==2.9.13) (1.2.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio>=5.0.2->flask-socketio->lumibot==2.9.13) (0.14.0)

# %%
from lumibot.brokers import Alpaca
from lumibot.backtesting import YahooDataBacktesting
from lumibot.strategies.strategy import Strategy
from lumibot.traders import Trader
from datetime import datetime
from alpaca_trade_api import REST
from timedelta import Timedelta
from finbert_utils import estimate_sentiment

# %% [markdown]
# # Importing Essential Libraries and Classes
#
# In this cell, we import the necessary libraries and classes to set up our trading environment and sentiment analysis capabilities:
#
# - **Alpaca**: A brokerage class from `lumibot.brokers` to interact with the Alpaca trading platform.
# - **YahooDataBacktesting**: A class from `lumibot.backtesting` for obtaining historical data from Yahoo Finance for backtesting purposes.
# - **Strategy**: The base strategy class from `lumibot.strategies` that we will inherit to define our custom trading strategy.
# - **Trader**: A class from `lumibot.traders` to execute trades based on the signals generated by our strategy.
# - **datetime**: From the built-in `datetime` module, for handling dates and times, crucial for timestamping trades and managing historical data.
# - **REST**: Imported from `alpaca_trade_api`, providing REST API access to the Alpaca platform for trading actions and data retrieval.
# - **Timedelta**:  is used for calculating time differences.
# - **estimate_sentiment**: A function from `finbert_utils` for estimating the sentiment of financial texts, which can influence trading decisions.
#
# This setup is foundational for creating a trading strategy that utilizes sentiment analysis and can execute trades automatically through the Alpaca platform, with backtesting capabilities using Yahoo Finance data.

# %%
API_KEY="Your api key here"
API_SECRET="Your api key here"
BASE_URL="https://paper-api.alpaca.markets/v2"
ALPACA_CREDS={
    "API_KEY":API_KEY,
    "API_SECRET":API_SECRET,
    "PAPER":True
}

# %% [markdown]
# # Configuration of Alpaca API Credentials
#
# Here, we establish the API credentials necessary for connecting to the Alpaca trading platform. This involves specifying our API key, API secret, and the base URL for Alpaca's paper trading API. These credentials are then organized into a dictionary named `ALPACA_CREDS` which will be used throughout the project to authenticate our requests to Alpaca. Paper trading mode is enabled (`"PAPER": True`), allowing us to test our trading strategies in a simulated environment without financial risk.

# %%
class MLTrader(Strategy):
    def initialize(self,symbol:str="SPY",cash_at_risk:float=0.5):
        self.symbol=symbol
        self.sleeptime="24H"
        self.last_trade=None
        self.cash_at_risk=cash_at_risk
        self.api=REST(base_url=BASE_URL,key_id=API_KEY,secret_key=API_SECRET)
        
    def position_sizing(self):
        cash=self.get_cash()
        last_price=self.get_last_price(self.symbol)
        quantity=round(cash*self.cash_at_risk/last_price,0)
        return cash,last_price,quantity
    
#This formula guides how much of our cash balance we use per trade. cash_at_risk of 0.5 menas that for each trade we are using 50% of our remaining cash balance
    def get_dates(self):
        today=self.get_datetime()
        three_days_prior=today-Timedelta(days=3)
        return today.strftime('%Y-%m-%d'),three_days_prior.strftime('%Y-%m-%d')
    
    def get_sentiment(self):
        today,three_days_prior =self.get_dates()
        news=self.api.get_news(symbol=self.symbol,
                                start=three_days_prior,
                                end=today)
        news=[ev.__dict__["_raw"]["headline"] for ev in news]
        probability, sentiment=estimate_sentiment(news)
        return probability, sentiment, news 
        
            
    def on_trading_iteration(self):
        cash,last_price,quantity=self.position_sizing()
        probability, sentiment, news=self.get_sentiment()
        if cash>last_price:
            if sentiment=="positive" and probability> 0.999:
                #print(probability, sentiment, news)
                if self.last_trade=="sell":
                    self.sell_all()
                order=self.create_order(
                    self.symbol,
                    quantity,
                    "buy",
                    type="market",
                    take_profit_price=last_price*1.20,
                    stop_loss_price=last_price*0.95,
                    )
                self.submit_order(order)
                self.last_trade="buy"
            
            elif sentiment=="negative" and probability> 0.999:
                #print(probability, sentiment, news)
                if self.last_trade=="buy":
                    self.sell_all()
                order=self.create_order(
                    self.symbol,
                    quantity,
                    "sell",
                    type="market",
                    take_profit_price=last_price*0.8,
                    stop_loss_price=last_price*1.05,
                    )
                self.submit_order(order)
                self.last_trade="sell"
            
start_date=datetime(2020,1,1)
end_date=datetime(2024,4,5)
broker=Alpaca(ALPACA_CREDS)

strategy=MLTrader(name="mlstrat",
                    broker=broker,
                    parameters={"symbol":"SPY",
                            "cash_at_risk":0.5}
                )

strategy.backtest(
    YahooDataBacktesting,
    start_date,
    end_date,
    parameters={"symbol":"SPY","cash_at_risk":0.5}
)
# Out:
# Starting backtest for MLTrader...
# INFO:backtest_stats:Starting backtest...
# Progress || 100.00%  [Elapsed: 0:15:09 ETA: 0:00:00] Portfolio Val: 562,140.67
# Creating trades plot...
#
# Creating indicators plot...
#
# Creating tearsheet...
# {'cagr': 0.5009147055138508,
#  'volatility': 0.5769104744862977,
#  'sharpe': 0.7778758123391128,
#  'max_drawdown': {'drawdown': 0.6475489346357906,
#   'date': Timestamp('2020-05-13 09:30:00-0400', tz='America/New_York')},
#  'romad': 0.7735549836022614,
#  'total_return': 4.621406662780757}

# %% [markdown]
# # MLTrader Strategy Definition and Backtest Setup
#
# This cell defines `MLTrader`, a custom trading strategy class inheriting from `lumibot`'s `Strategy`. It's designed to trade based on sentiment analysis, with specific attention to managing risk and optimizing trade positions. Here's an overview of its key components:
#
# 1. **Initialization (`initialize`)**: Sets up the trading symbol (e.g., SPY), the amount of cash at risk per trade, and initializes the Alpaca API for trading actions.
# 2. **Position Sizing (`position_sizing`)**: Determines the amount of stock to buy or sell based on the available cash and a predefined risk parameter.
# 3. **Sentiment Analysis (`get_sentiment`)**: Fetches recent news headlines for the trading symbol and estimates their sentiment, guiding the trading decisions.
# 4. **Trading Logic (`on_trading_iteration`)**: Executes buy or sell orders based on sentiment analysis, with conditions for entry and exit, including take profit and stop loss levels.
#
# ## Visual Representation
#
# - **Position Sizing Formula**: `quantity = round((cash * cash_at_risk) / last_price)`
# - **Trading Decision Flowchart**:
#
# ![Trading Decision Flowchart](flowchart.png)
#
#
# This flowchart should depict how the trading strategy decides when to enter or exit trades based on the sentiment analysis and predefined thresholds for action.
#
# ## Backtesting the Strategy
#
# Finally, we set up a backtest for this strategy using historical data from Yahoo Finance, spanning from January 1, 2020, to April 5, 2024. The backtest uses the Alpaca broker for simulated trades within this period.
